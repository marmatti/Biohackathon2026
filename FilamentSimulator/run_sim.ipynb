# %%
! python simulator/runner.py \
--config configs/base.yaml \
--output-root outputs/base \
--n-runs 10
# Out:
# Base config: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/configs/base.yaml
# Output root: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/outputs/base
# Number of runs: 10
# Seeds: [152695926, 415468701, 523886974, 640249577, 1039084854, 1399345201, 1422009853, 1427490761, 1794326215, 2051533499]
# [1/10] Saved run to outputs/base/run_000_seed_152695926
# [2/10] Saved run to outputs/base/run_001_seed_415468701
# [3/10] Saved run to outputs/base/run_002_seed_523886974
# [4/10] Saved run to outputs/base/run_003_seed_640249577
# [5/10] Saved run to outputs/base/run_004_seed_1039084854
# [6/10] Saved run to outputs/base/run_005_seed_1399345201
# [7/10] Saved run to outputs/base/run_006_seed_1422009853
# [8/10] Saved run to outputs/base/run_007_seed_1427490761
# [9/10] Saved run to outputs/base/run_008_seed_1794326215
# [10/10] Saved run to outputs/base/run_009_seed_2051533499
# All runs completed.

# %%
! python simulator/runner.py \
--config configs/low_contrast.yaml \
--output-root outputs/low_contrast \
--n-runs 10
# Out:
# Base config: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/configs/low_contrast.yaml
# Output root: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/outputs/low_contrast
# Number of runs: 10
# Seeds: [16380820, 177502232, 228474404, 581567419, 635922746, 852085332, 896681152, 1572003314, 1788528570, 1812838906]
# [1/10] Saved run to outputs/low_contrast/run_000_seed_16380820
# [2/10] Saved run to outputs/low_contrast/run_001_seed_177502232
# [3/10] Saved run to outputs/low_contrast/run_002_seed_228474404
# [4/10] Saved run to outputs/low_contrast/run_003_seed_581567419
# [5/10] Saved run to outputs/low_contrast/run_004_seed_635922746
# [6/10] Saved run to outputs/low_contrast/run_005_seed_852085332
# [7/10] Saved run to outputs/low_contrast/run_006_seed_896681152
# [8/10] Saved run to outputs/low_contrast/run_007_seed_1572003314
# [9/10] Saved run to outputs/low_contrast/run_008_seed_1788528570
# ...

# %%
! python simulator/runner.py \
--config configs/lowlow_contrast.yaml \
--output-root outputs/lowlow_contrast \
--n-runs 10
# Out:
# Base config: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/configs/lowlow_contrast.yaml
# Output root: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/outputs/lowlow_contrast
# Number of runs: 10
# Seeds: [37292020, 584200531, 590164963, 622488904, 977187554, 1361031125, 1479020743, 1508173825, 1562888265, 1664480892]
# [1/10] Saved run to outputs/lowlow_contrast/run_000_seed_37292020
# [2/10] Saved run to outputs/lowlow_contrast/run_001_seed_584200531
# [3/10] Saved run to outputs/lowlow_contrast/run_002_seed_590164963
# [4/10] Saved run to outputs/lowlow_contrast/run_003_seed_622488904
# [5/10] Saved run to outputs/lowlow_contrast/run_004_seed_977187554
# [6/10] Saved run to outputs/lowlow_contrast/run_005_seed_1361031125
# [7/10] Saved run to outputs/lowlow_contrast/run_006_seed_1479020743
# [8/10] Saved run to outputs/lowlow_contrast/run_007_seed_1508173825
# [9/10] Saved run to outputs/lowlow_contrast/run_008_seed_1562888265
# ...

# %%
! python simulator/runner.py \
--config configs/low_contrast_high_bgnoise.yaml \
--output-root outputs/low_contrast_high_bgnoise \
--n-runs 10
# Out:
# Base config: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/configs/low_contrast_high_bgnoise.yaml
# Output root: /home/rzhu/Desktop/packages/FilamentSimulator/FilamentSimulator/outputs/low_contrast_high_bgnoise
# Number of runs: 10
# Seeds: [139370964, 158896082, 255436339, 375442197, 424234467, 683623528, 1129783834, 1150609191, 1483548791, 1844513025]
# [1/10] Saved run to outputs/low_contrast_high_bgnoise/run_000_seed_139370964
# [2/10] Saved run to outputs/low_contrast_high_bgnoise/run_001_seed_158896082
# [3/10] Saved run to outputs/low_contrast_high_bgnoise/run_002_seed_255436339
# [4/10] Saved run to outputs/low_contrast_high_bgnoise/run_003_seed_375442197
# [5/10] Saved run to outputs/low_contrast_high_bgnoise/run_004_seed_424234467
# [6/10] Saved run to outputs/low_contrast_high_bgnoise/run_005_seed_683623528
# [7/10] Saved run to outputs/low_contrast_high_bgnoise/run_006_seed_1129783834
# ...
